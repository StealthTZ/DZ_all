# %%
from pycaret.regression import *
import pandas as pd

# %%
data=pd.read_csv('call_2023.csv')

# %%
data.describe()
# Out:
#                date     year         month          call
# count  18105.000000  18105.0  18105.000000  18105.000000
# mean      15.915493   2023.0      6.569014     77.460867
# std        8.723767      0.0      3.428665     43.197662
# min        1.000000   2023.0      1.000000      0.000000
# 25%        8.000000   2023.0      4.000000     46.000000
# 50%       16.000000   2023.0      7.000000     81.000000
# 75%       23.000000   2023.0     10.000000    109.000000
# max       31.000000   2023.0     12.000000    264.000000

# %%
exp = setup(data,target='call',session_id=42)
# Out:
# <style type="text/css">
# #T_9e37e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9e37e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9e37e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9e37e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e37e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9e37e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9e37e_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_9e37e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9e37e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9e37e_row1_col1" class="data row1 col1" >call</td>
#     </tr>
#     <tr>
#       <th id="T_9e37e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_61fd1 th {
#   text-align: left;
# }
# ...

# %%
final_model = create_model(best_model)
# Out:
# <style type="text/css">
# #T_1c4b9_row10_col0, #T_1c4b9_row10_col1, #T_1c4b9_row10_col2, #T_1c4b9_row10_col3, #T_1c4b9_row10_col4, #T_1c4b9_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1c4b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c4b9_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1c4b9_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1c4b9_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1c4b9_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1c4b9_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_1c4b9_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
prediction = predict_model(final_model,data)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a38b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a38b9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a38b9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a38b9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a38b9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a38b9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a38b9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a38b9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a38b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a38b9_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_a38b9_row0_col1" class="data row0 col1" >8.5815</td>
# ...

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
import pandas as pd

# %%
df=pd.read_csv('time.csv')

# %%
df.describe()
# Out:
#                time          call
# count  18105.000000  18105.000000
# mean   45111.118809     77.460867
# std      104.579474     43.197662
# min    44929.354167      0.000000
# 25%    45019.750000     46.000000
# 50%    45112.614583     81.000000
# 75%    45201.479167    109.000000
# max    45291.875000    264.000000

# %%
print(df.head())
# Out:
#            time  call
# 0  44929.354167    57
# 1  44929.364583    37
# 2  44929.375000    60
# 3  44929.385417    80
# 4  44929.395833    98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18105 entries, 0 to 18104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    18105 non-null  float64
#  1   call    18105 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 283.0 KB

# %%
import xlrd

# %%
df['time'] = df['time'].apply(lambda x: xlrd.xldate_as_datetime(x, 0))

# %%
print(df.head())
# Out:
#                  time  call
# 0 2023-01-03 08:30:00    57
# 1 2023-01-03 08:45:00    37
# 2 2023-01-03 09:00:00    60
# 3 2023-01-03 09:15:00    80
# 4 2023-01-03 09:30:00    98

# %%
# df.to_csv('new.csv',index=False,sep=',')

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
print(df['time'].dtype)
# Out:
# datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18105 entries, 0 to 18104
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    18105 non-null  datetime64[ns]
#  1   call    18105 non-null  int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 283.0 KB

# %%
df.plot(x='time', y='call', kind='line', title='График зависимости y от x', xlabel='x', ylabel='y', figsize=(10, 6), color='red')
# Out:
# <AxesSubplot: title={'center': 'График зависимости y от x'}, xlabel='x', ylabel='y'>

# %%
from pycaret.time_series import *
s = setup(data = df, target = 'call', fh = 30)
# Out:
# <style type="text/css">
# #T_39bc5_row25_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_39bc5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39bc5_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_39bc5_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39bc5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_39bc5_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_39bc5_row0_col1" class="data row0 col1" >8808</td>
#     </tr>
#     <tr>
#       <th id="T_39bc5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_39bc5_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_39bc5_row1_col1" class="data row1 col1" >call</td>
#     </tr>
#     <tr>
#       <th id="T_39bc5_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_00c92 th {
#   text-align: left;
# }
# #T_00c92_row0_col0, #T_00c92_row0_col5, #T_00c92_row0_col7, #T_00c92_row1_col0, #T_00c92_row1_col1, #T_00c92_row1_col2, #T_00c92_row1_col3, #T_00c92_row1_col4, #T_00c92_row1_col6, #T_00c92_row2_col0, #T_00c92_row2_col1, #T_00c92_row2_col2, #T_00c92_row2_col3, #T_00c92_row2_col4, #T_00c92_row2_col5, #T_00c92_row2_col6, #T_00c92_row2_col7, #T_00c92_row3_col0, #T_00c92_row3_col1, #T_00c92_row3_col2, #T_00c92_row3_col3, #T_00c92_row3_col4, #T_00c92_row3_col5, #T_00c92_row3_col6, #T_00c92_row3_col7, #T_00c92_row4_col0, #T_00c92_row4_col1, #T_00c92_row4_col2, #T_00c92_row4_col3, #T_00c92_row4_col4, #T_00c92_row4_col5, #T_00c92_row4_col6, #T_00c92_row4_col7 {
#   text-align: left;
# }
# #T_00c92_row0_col1, #T_00c92_row0_col2, #T_00c92_row0_col3, #T_00c92_row0_col4, #T_00c92_row0_col6, #T_00c92_row1_col5, #T_00c92_row1_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_00c92_row0_col8 {
# ...

# %%
predictions = predict_model(best_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_1906b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1906b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1906b_level0_col1" class="col_heading level0 col1" >MASE</th>
#       <th id="T_1906b_level0_col2" class="col_heading level0 col2" >RMSSE</th>
#       <th id="T_1906b_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_1906b_level0_col4" class="col_heading level0 col4" >RMSE</th>
#       <th id="T_1906b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#       <th id="T_1906b_level0_col6" class="col_heading level0 col6" >SMAPE</th>
#       <th id="T_1906b_level0_col7" class="col_heading level0 col7" >R2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1906b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1906b_row0_col0" class="data row0 col0" >Grand Means Forecaster</td>
# ...

# %%
plot_model(best_model, plot = 'line')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 plot_model(best_model, plot = 'line')
#
# File ~\anaconda3\Lib\site-packages\pycaret\utils\generic.py:965, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     963     if globals_d[name] is None:
#     964         raise ValueError(message)
# --> 965 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pycaret\time_series\forecasting\functional.py:1400, in plot_model(estimator, plot, return_fig, return_data, verbose, display_format, data_kwargs, fig_kwargs, save)
#    1163 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1164 def plot_model(
#    1165     estimator: Optional[Any] = None,
#    (...)
#    1173     save: Union[str, bool] = False,
#    1174 ) -> Optional[Tuple[str, list]]:
#    1175     """
# ...
